# %% [markdown]
# # Bubble Maps

# %%
import pandas as pd
import plotly.graph_objects as go

data=pd.read_csv('/home/kirti/Data_sets/district wise population and centroids.csv')
data=data.sort_values('Population in 2011',ascending=False)
data
# Out:
#                  State             District   Latitude  Longitude  \
# 261        Maharashtra                Thane  19.698768  72.798827
# 255        Maharashtra                 Pune  18.516962  74.129229
# 428        West Bengal          Murshidabad  24.259507  88.168169
# 322          Rajasthan               Jaipur  27.033459  75.771173
# 252        Maharashtra               Nashik  20.266913  74.038242
# ..                 ...                  ...        ...        ...
# 285            Mizoram             Serchhip  23.263865  92.914158
# 284            Mizoram                Saiha  22.357448  93.028279
# 15   Arunachal Pradesh  Lower Dibang Valley  28.326517  95.765673
# 18   Arunachal Pradesh               Tawang  27.680684  91.825042
# 20   Arunachal Pradesh          Upper Siang  28.830924  95.001558
#
#      Population in 2001  Population in 2011
# 261             8131849            11060148
# 255             7232555             9429408
# ...

# %%
colors=["royalblue","crimson","lightseagreen","orange","lightgrey"]
limits=[(0,10),(10,50),(50,120),(120,250),(250,431)]
scale=50000
fig=go.Figure()

for i in range(len(limits)):
    lim=limits[i]
    df=data[lim[0]:lim[1]]
    fig.add_trace(go.Scattergeo
                  (geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                  featureidkey='properties.ST_NM',
                  locationmode='geojson-id',
                  lon=df['Longitude'],
                  lat=df['Latitude'],
                  
                    marker=dict(
                      size=df['Population in 2011']/scale,
                      color=colors[i],
                      line_color='rgb(40,40,40)',
                      line_width=0.5,
                      sizemode = 'area')))
fig.update_geos(
         
         projection=dict(
                   type='conic conformal',
                    parallels=[12.4729,35.1728055],
                   rotation={'lat':24,'lon':80}),
         lonaxis={'range':[68,98]},
         lataxis={'range':[6,38]})
    
fig.show()
# Out:
# <div>                            <div id="44607230-dbe4-48dc-b290-bea237e3c79c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44607230-dbe4-48dc-b290-bea237e3c79c")) {                    Plotly.newPlot(                        "44607230-dbe4-48dc-b290-bea237e3c79c",                        [{"featureidkey": "properties.ST_NM", "geojson": "https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson", "lat": [19.698767747440268, 18.51696171428573, 24.25950655391121, 27.033459290187892, 20.266912871287147, 21.25761372772093, 25.392038662316445, 25.40297114503818, 23.56410971055088, 16.782718320784902], "locationmode": "geojson-id", "lon": [72.79882742564581, 74.1292288163
# ...
